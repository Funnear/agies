# %% [markdown]
# # 🎵 MusicBrainz API Exploration — EDM Release Groups, Tags & Labels
#
# This notebook explores the MusicBrainz live REST API to gather metadata for electronic music (EDM) sub-genre classification and curation analysis.
#
# ### Objectives
# * Query total available records for target genre tags (`tag:edm`).
# * Fetch sample release group payloads with pagination and custom rate-limiting.
# * Normalize nested JSON structures into tabular DataFrames.
# * Extract high-value categorical features: **Artists**, **Primary Types**, **Genre Tags**, and **Record Labels** (e.g., *Ultra Music*, *Bad Boy Records*, *Big Beat*).

# %% [markdown]
# ## 1. Environment & Utility Imports

# %%
import requests
import pandas as pd
import time
import logging
import os
import ast
from collections import Counter

from data_ravers_utils.file_handler import save_df_pickle, read_df_pickle, save_df_as_csv
from data_ravers_utils import eda_utils
from src.agies.integration.api_helpers import fetch_raw_api_sample

# %% [markdown]
# ## 2. API Configuration & Live Volume Check

# %%
# API Configuration Constants
HEADERS = {"User-Agent": "AGIes/0.1 (info@dataravers.space)"}
BASE_URL = "https://musicbrainz.org/ws/2/release-group/"
DEFAULT_TAG = "edm"
FETCH_LIMIT = 10
RATE_LIMIT_DELAY = 1.2
REQUEST_TIMEOUT=30

# %%
def get_mb_tag_total_count(tag_name=DEFAULT_TAG):

    """
    Fetch the live total record count for a specific tag on MusicBrainz.
    """
    params={"query": f"tag:{tag_name}", "fmt": "json", "limit": 1}
    data = fetch_raw_api_sample(BASE_URL, params=params, headers=HEADERS, timeout=REQUEST_TIMEOUT)
    
    total_count = data.get("count", 0) if data else 0
    return total_count

# Query live total count
total_edm_records = get_mb_tag_total_count()

# %% [markdown]
# ## 3. Fetch & Store Sample Batch
#
# Pull a sample batch while respecting the 1 request/second rate limit, then save locally.

# %%
def fetch_raw_musicbrainz_sample(sample_limit, tag=DEFAULT_TAG, limit=FETCH_LIMIT):
    """Fetch a small sample batch for initial EDA without full collection wait times."""
    raw_sample = []
    
    for offset in range(0, sample_limit, limit):
        params = {
            "query": f"tag:{tag}",
            "fmt": "json",
            "limit": FETCH_LIMIT,
            "offset": offset
        }
        
        # Use your generic API helper for the individual request
        data = fetch_raw_api_sample(BASE_URL, params=params, headers=HEADERS, timeout=REQUEST_TIMEOUT)
            
        if data:
            records = data.get("release-groups", [])
            raw_sample.extend(records)
            print(f"Fetched sample offset {offset} ({len(raw_sample)} records)")
        # Keep rate limiting to prevent HTTP 503 blocks
        time.sleep(RATE_LIMIT_DELAY)
        
    return raw_sample

# Execute sample fetch
raw_sample_data = fetch_raw_musicbrainz_sample(sample_limit=15)
df_sample = pd.DataFrame({"raw_payload": raw_sample_data})
print(f"Collected {len(df_sample)} records for exploration.")

# 1. Ensure the 'data' directory exists locally
os.makedirs("data", exist_ok=True)
# Save raw sample binary pickle
save_df_pickle(df=df_sample, filename="musicbrainz_edm_raw_sample")
# Save flat CSV for quick manual viewing
save_df_as_csv(df=df_sample, filename="musicbrainz_edm_raw_sample")
print("Directory created and raw sample files successfully saved!")
# Out:
# Fetched sample offset 0 (10 records)
# Fetched sample offset 10 (20 records)
# Collected 20 records for exploration.
# Directory created and raw sample files successfully saved!

# %% [markdown]
# ## 4. Reload Sample & Normalize Payload

# %%
# Load sample from disk
df_raw=read_df_pickle("musicbrainz_edm_raw_sample")
print("DataFrame Shape:", df_raw.shape)
display(df_raw)

# Flatten raw JSON into a temporary DataFrame for EDA
df_samples = pd.json_normalize(df_raw["raw_payload"])
# 2. Convert list and dictionary columns to strings so unique/nunique operations don't fail
for col in df_samples.columns:
    if df_samples[col].apply(lambda x: isinstance(x, (list, dict))).any():
        df_samples[col] = df_samples[col].astype(str)
# Out:
# DataFrame Shape: (20, 1)
#                                           raw_payload
# 0   {'id': '4dc4fb78-e096-3f7b-9334-9defe9890ef8',...
# 1   {'id': '3b766d4f-7b6b-44a3-9b52-bff158484f40',...
# 2   {'id': '8a787daf-2a37-45a1-9ae1-53197eb79541',...
# 3   {'id': 'ddfc24ec-3376-4ad0-8279-ca47d579fcee',...
# 4   {'id': '7ba3a993-00b1-4627-a2e2-0e56127c039a',...
# 5   {'id': '15425b37-1009-4a66-854e-079d96609320',...
# 6   {'id': '860f4808-bea7-486b-ab96-26f578c03137',...
# 7   {'id': '766c938e-c006-4ee0-954e-6fadf3cc78ec',...
# 8   {'id': '5db6d28b-7486-49a6-ac43-beed4b4162bb',...
# 9   {'id': 'a94d5965-6f2e-43ac-af00-e01a2fccfd74',...
# 10  {'id': 'e676581b-27cc-4ce2-8279-ba40f314d3ac',...
# 11  {'id': '8491d2c6-6540-431a-9f52-aa25f0d89cfb',...
# 12  {'id': '7ef7bc6b-7e7f-4aec-97b2-69b58d1d79c4',...
# 13  {'id': 'a44fe580-981f-438d-b3f7-01ef2127b95c',...
# 14  {'id': '2ef79a8f-f461-4623-afe4-1306599f4250',...
# 15  {'id': '8d703d22-6ca2-466c-8452-d09a39ecc53e',...
# 16  {'id': 'd2ca6ba2-30fd-428a-a8da-431157e7538a',...
# 17  {'id': '83af8381-a547-40b2-bf10-576034951db9',...
# 18  {'id': '82d2c13e-dc7a-488e-8c47-0fe86065d6d1',...
# 19  {'id': '90dc787f-0ee6-4781-9b00-8494da1313de',...

# %% [markdown]
# ## 5. Exploratory Data Analysis & Tag Extraction

# %%
# Generate report on 500 samples
eda_utils.print_eda_report(df_samples)

# Helper function to extract tag names
def extract_tag_names(raw_tags_str):
    """Convert the stringified tags list back into just a list of tag names."""
    try:
        tags_list = ast.literal_eval(raw_tags_str)
        return [t['name'] for t in tags_list]
    except (ValueError, SyntaxError, TypeError):
        return []
# Parse tag names and compute frequencies    
df_samples['tag_names'] = df_samples['tags'].apply(extract_tag_names)
all_tags = [tag for tags_list in df_samples['tag_names'] for tag in tags_list]
tag_counts = Counter(all_tags)
display(pd.Series(tag_counts).sort_values(ascending=False).head(20))
# Out:
# ================= Dataset =================
# Dataset has shape (20, 14)
#
# Dataset has numerical data in columns: ['score', 'count']
# - Column "count" has 3 unique values.
#   -- Unique values are:
#  [3 1 2]
# - Column "score" has 1 unique values.
#   -- Unique values are:
#  [100]
#
# Dataset has categorical data in columns: ['id', 'type-id', 'primary-type-id', 'artist-credit-id', 'title', 'first-release-date', 'primary-type', 'artist-credit', 'releases', 'tags', 'secondary-types', 'secondary-type-ids']
# - Column "id" has 20 unique values.
#   -- Unique values are:
#  <StringArray>
# ['4dc4fb78-e096-3f7b-9334-9defe9890ef8',
#  '3b766d4f-7b6b-44a3-9b52-bff158484f40',
#  '8a787daf-2a37-45a1-9ae1-53197eb79541',
#  'ddfc24ec-3376-4ad0-8279-ca47d579fcee',
#  '7ba3a993-00b1-4627-a2e2-0e56127c039a',
#  '15425b37-1009-4a66-854e-079d96609320',
#  '860f4808-bea7-486b-ab96-26f578c03137',
#  '766c938e-c006-4ee0-954e-6fadf3cc78ec',
#  '5db6d28b-7486-49a6-ac43-beed4b4162bb',
#  'a94d5965-6f2e-43ac-af00-e01a2fccfd74',
#  'e676581b-27cc-4ce2-8279-ba40f314d3ac',
#  '8491d2c6-6540-431a-9f52-aa25f0d89cfb',
#  '7ef7bc6b-7e7f-4aec-97b2-69b58d1d79c4',
#  'a44fe580-981f-438d-b3f7-01ef2127b95c',
#  '2ef79a8f-f461-4623-afe4-1306599f4250',
#  '8d703d22-6ca2-466c-8452-d09a39ecc53e',
#  'd2ca6ba2-30fd-428a-a8da-431157e7538a',
#  '83af8381-a547-40b2-bf10-576034951db9',
#  '82d2c13e-dc7a-488e-8c47-0fe86065d6d1',
#  '90dc787f-0ee6-4781-9b00-8494da1313de']
# Length: 20, dtype: str
# - Column "type-id" has 5 unique values.
#   -- Unique values are:
#  <StringArray>
# ['f529b476-6e62-324f-b0aa-1f3e33d313fc',
#  '6d0c5bf6-7a33-3420-a519-44fc63eedebf',
#  'dd2a21e1-0c00-3729-a7a0-de60b84eb5d1',
#  'd6038452-8ee0-3f68-affc-2de9a1ede0b9',
#  '0c60f497-ff81-3818-befd-abfc84a4858b']
# Length: 5, dtype: str
# - Column "primary-type-id" has 3 unique values.
#   -- Unique values are:
#  <StringArray>
# ['f529b476-6e62-324f-b0aa-1f3e33d313fc',
#  '6d0c5bf6-7a33-3420-a519-44fc63eedebf',
#  'd6038452-8ee0-3f68-affc-2de9a1ede0b9']
# Length: 3, dtype: str
# - Column "artist-credit-id" has 19 unique values.
#   -- Unique values are:
#  <StringArray>
# ['2c705a8a-f62e-3dc0-b0df-119046e3b33f',
#  'eba87b59-d1ba-3789-a7d8-e0b7d2d4ccec',
#  '1ea14807-0ca4-3572-9424-8e1e34428e13',
#  '95c74769-a6dc-30bb-842d-d8a3e9c3e6ff',
#  'bfe20bbd-786b-3e29-817d-6c7230b9e4d8',
#  '8bd18830-7256-3e05-a5bc-3618c186c14e',
#  'bbb39fff-624a-3a8f-ba45-72be335920cf',
#  'cde6a800-9ccf-32c1-9173-800e1593b03e',
#  '22ea8778-5ff8-3d9f-bffb-0c941bf82c65',
#  'd91c382c-f45d-3602-a233-3728eb3ce726',
#  'f29cf4f6-a675-3f54-9c27-53ff6e5b8cf5',
#  '60f0798d-8a7c-313b-958c-eb69fa37e013',
#  '94af4a6f-d21d-3a6f-b786-0824beb16b7c',
#  'bd37173b-5422-39fe-99c0-6865ac252e72',
#  'c81a0d40-0ae4-3428-87ad-1ada1daae031',
#  '022fe819-21c8-386c-9525-acf636d0364c',
#  '577ffcf6-38b3-3a0c-b37f-f63a0750bdb2',
#  'fa0edbc1-7f77-3894-861e-39a51c7d40f3',
#  '70e28257-8547-3096-9db4-1417138241b0']
# Length: 19, dtype: str
# - Column "title" has 20 unique values.
#   -- Unique values are:
#  <StringArray>
# [           'More Than Alive',            'Stuck on Repeat',
#                  'Ultra.2010',                    'Harmony',
#               'Demonstration',                    'Ah Yeah',
#          'Hello Good Morning',                'Madd Circus',
#   'Dance Under the Influence',  'Neon Future III (Remixes)',
#                   'This Time',                 'Like to be',
#    'Faccio quello che voglio',        'Drunk Groove (edit)',
#  'Mario Cars 2: 64 THE REMIX',           'The burning song',
#                     'Kashmir',             'Pink Champagne',
#                        'MORE',                   'Peroxide']
# Length: 20, dtype: str
# - Column "first-release-date" has 20 unique values.
#   -- Unique values are:
#  <StringArray>
# [      '2003', '2011-03-31', '2009-11-03',       '2010', '2013-11-04',
#  '2013-04-29', '2010-03-30', '2010-09-27', '2016-05-20', '2019-02-15',
#  '2017-03-24', '2019-04-12', '2018-07-13', '2017-12-29', '2016-12-03',
#  '2020-02-04', '2020-07-30', '2016-08-10', '2020-10-29', '2020-07-14']
# Length: 20, dtype: str
# - Column "primary-type" has 3 unique values.
#   -- Unique values are:
#  <StringArray>
# ['Album', 'EP', 'Single']
# Length: 3, dtype: str
# - Column "artist-credit" has 19 unique values.
#   -- Unique values are:
#  <StringArray>
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  '[{'name': 'Da Buzz', 'artist': {'id': '1bd50cb2-09b8-4539-b660-af585cb3e40b', 'name': 'Da Buzz', 'sort-name': 'Buzz, Da'}}]',
#                                                                                                                             '[{'name': 'Wanessa Camargo', 'artist': {'id': 'd3acca3b-2a75-4b2d-b15c-a5f6ee723b45', 'name': 'Wanessa Camargo', 'sort-name': 'Wanessa Camargo', 'aliases': [{'sort-name': 'Camargo, Wanessa Godói', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Wanessa Godói Camargo', 'locale': None, 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Wanessa', 'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc', 'name': 'Wanessa', 'locale': None, 'type': 'Artist name', 'primary': None, 'begin-date': '2007', 'end-date': None}, {'sort-name': 'Buaiz, Wanessa Godói Camargo', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Wanessa Godói Camargo Buaiz', 'locale': None, 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Camargo, Wanessa', 'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc', 'name': 'Wanessa Camargo', 'locale': None, 'type': 'Artist name', 'primary': None, 'begin-date': '2000', 'end-date': '2007'}]}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '[{'name': 'Dave Audé', 'artist': {'id': 'f8d03e4c-8393-4a15-9244-acd3f03bfecd', 'name': 'Dave Audé', 'sort-name': 'Audé, Dave', 'aliases': [{'sort-name': 'Aude, Dave', 'name': 'Dave Aude', 'locale': 'en', 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Audé, David P.', 'name': 'David P. Audé', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                  '[{'name': 'Laurent Wolf', 'artist': {'id': '282269b2-b468-4cf9-aea5-20c632429b85', 'name': 'Laurent Wolf', 'sort-name': 'Wolf, Laurent', 'aliases': [{'sort-name': 'Afro Dynamic III by Laurent Wolf', 'name': 'Afro Dynamic III by Laurent Wolf', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Laurent Wolf Pres. Afro-Dynamic', 'name': 'Laurent Wolf Pres. Afro-Dynamic', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Laurant Wolf', 'name': 'Laurant Wolf', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Laurent Wolf presents Afro Dynamic', 'name': 'Laurent Wolf presents Afro Dynamic', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Laurent Woll', 'name': 'Laurent Woll', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '[{'name': 'Tinie Tempah', 'artist': {'id': '3cce3d37-d44f-46a2-b1e3-cd7247d5015c', 'name': 'Tinie Tempah', 'sort-name': 'Tempah, Tinie'}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 '[{'name': 'Will Sparks', 'artist': {'id': '75b187e8-7848-4cc6-93f4-73fe4b3ad5b2', 'name': 'Will Sparks', 'sort-name': 'Sparks, Will', 'aliases': [{'sort-name': 'William James Sparks', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'William James Sparks', 'locale': 'en_AU', 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '[{'name': 'Diddy – Dirty Money', 'artist': {'id': '480cdd78-e54e-4518-9ec9-572a62d7e1e1', 'name': 'Diddy – Dirty Money', 'sort-name': 'Diddy – Dirty Money', 'aliases': [{'sort-name': 'Dirty Money', 'name': 'Dirty Money', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                                                                                                                                                                                     '[{'name': 'Detroit Grand Pubahs', 'artist': {'id': 'd80972fd-c950-45ef-bba6-31a94bc276ce', 'name': 'Detroit Grand Pubahs', 'sort-name': 'Detroit Grand Pubahs', 'aliases': [{'sort-name': 'Detriot Grand Pu Bahs', 'name': 'Detriot Grand Pu Bahs', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'The Detroit Grand Pubahs', 'name': 'The Detroit Grand Pubahs', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Detroit Grand Pu Bahs', 'name': 'Detroit Grand Pu Bahs', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Detroit Grand Poobah', 'name': 'Detroit Grand Poobah', 'locale': None, 'type': None, 'primary': None, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        '[{'name': 'Sanjoy', 'artist': {'id': 'ef33e4e7-2e6c-406e-98e0-f0edcf3147ca', 'name': 'Sanjoy', 'sort-name': 'Sanjoy', 'disambiguation': 'Sanjoy Deb'}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         '[{'name': 'Steve Aoki', 'artist': {'id': 'a39acc4a-985e-4173-a9ed-f325f2d3bc1c', 'name': 'Steve Aoki', 'sort-name': 'Aoki, Steve', 'aliases': [{'sort-name': 'Aoki, Steven Hiroyuki', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Steven Hiroyuki Aoki', 'locale': 'en', 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'スティーヴン・ヒロユキ・アオキ', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'スティーヴン・ヒロユキ・アオキ', 'locale': 'ja', 'type': 'Legal name', 'primary': True, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '[{'name': 'Kayzo', 'artist': {'id': 'e57634b1-01f3-4dc9-bd6b-0672c8e0665c', 'name': 'Kayzo', 'sort-name': 'Kayzo', 'disambiguation': 'Hayden Capuozzo', 'aliases': [{'sort-name': 'Capuozzo, Hayden', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Hayden Capuozzo', 'locale': None, 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 '[{'name': 'DJ Matt Black', 'artist': {'id': 'e7d88d98-11b4-491d-9a88-a45791fab6c0', 'name': 'DJ Matt Black', 'sort-name': 'Matt Black, DJ', 'disambiguation': 'English-born songwriter, record producer, and DJ', 'aliases': [{'sort-name': 'Belcher, Matthew', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Matthew Belcher', 'locale': None, 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '[{'name': 'Rovazzi', 'artist': {'id': '9c12f702-a317-40a5-b6cf-f2094b74a6d6', 'name': 'Fabio Rovazzi', 'sort-name': 'Rovazzi, Fabio', 'aliases': [{'sort-name': 'Piccolrovazzi, Fabio', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Fabio Piccolrovazzi', 'locale': None, 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}]}}]',
#  '[{'joinphrase': ' & ', 'name': 'MARUV', 'artist': {'id': '23d0ffbe-f372-443e-81b2-28048bdea37f', 'name': 'MARUV', 'sort-name': 'MARUV', 'aliases': [{'sort-name': 'SHLAKOBLOCHINA', 'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc', 'name': 'Shlakoblochina', 'locale': None, 'type': 'Artist name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Popeliukh, Anna Borysivna', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Anna Borysivna Popeliukh', 'locale': 'en', 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Корсун, Анна Борисівна', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Анна Борисівна Корсун', 'locale': 'uk', 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Корсун, Анна Борисовна', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Анна Борисовна Корсун', 'locale': 'ru', 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}]}}, {'name': 'Boosin', 'artist': {'id': 'f7cd9a32-e5a0-47dd-8c6c-cb86d982a3ad', 'name': 'Boosin', 'sort-name': 'Boosin'}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        '[{'name': 'Mario Cars 2 Tune Crew', 'artist': {'id': '75618062-adc6-4709-9bae-5dcfd638133d', 'name': 'Mario Cars 2 Tune Crew', 'sort-name': 'Mario Cars 2 Tune Crew'}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '[{'name': 'Mcnaida', 'artist': {'id': '33669d76-9c79-4ce1-a9b7-8ef1539c76b3', 'name': 'Mcnaida', 'sort-name': 'Mcnaida'}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               '[{'name': 'SaMaRoN', 'artist': {'id': '94f24304-e460-4644-87f5-6e92e6f4da0d', 'name': 'SaMaRoN', 'sort-name': 'SaMaRoN', 'disambiguation': 'Indian DJ', 'aliases': [{'sort-name': 'Prakash, Srijan', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Srijan Prakash', 'locale': None, 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Samaron', 'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc', 'name': 'Samaron', 'locale': 'en', 'type': 'Artist name', 'primary': True, 'begin-date': None, 'end-date': None}]}}]',
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     '[{'name': 'E‐girls', 'artist': {'id': '65784683-d180-44da-b385-050acf8ec4bb', 'name': 'E‐girls', 'sort-name': 'E‐girls'}}]',
#                                                                                                                                              '[{'name': 'MARUV', 'artist': {'id': '23d0ffbe-f372-443e-81b2-28048bdea37f', 'name': 'MARUV', 'sort-name': 'MARUV', 'aliases': [{'sort-name': 'SHLAKOBLOCHINA', 'type-id': '894afba6-2816-3c24-8072-eadb66bd04bc', 'name': 'Shlakoblochina', 'locale': None, 'type': 'Artist name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Popeliukh, Anna Borysivna', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Anna Borysivna Popeliukh', 'locale': 'en', 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Корсун, Анна Борисівна', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Анна Борисівна Корсун', 'locale': 'uk', 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}, {'sort-name': 'Корсун, Анна Борисовна', 'type-id': 'd4dcd0c0-b341-3612-a332-c0ce797b25cf', 'name': 'Анна Борисовна Корсун', 'locale': 'ru', 'type': 'Legal name', 'primary': None, 'begin-date': None, 'end-date': None}]}}]']
# Length: 19, dtype: str
# - Column "releases" has 20 unique values.
#   -- Unique values are:
#  <StringArray>
# ['[{'id': 'b52869be-99f8-40e5-bb8d-e83d80c68ab1', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'More Than Alive', 'status': 'Official'}, {'id': '1db581df-1e69-4c2b-acbb-d3f599d5310d', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'More Than Alive', 'status': 'Official'}, {'id': 'bdd29836-e44c-4b18-8101-d7f360f55d93', 'status-id': '518ffc83-5cde-34df-8627-81bff5093d92', 'title': 'More Than Alive', 'status': 'Promotion'}]',
#                                                                                                                                                                                                                                                                                                                '[{'id': '0ea8bc35-a2bc-44d4-ba15-307fc9fce744', 'status-id': '518ffc83-5cde-34df-8627-81bff5093d92', 'title': 'Stuck on Repeat', 'status': 'Promotion'}]',
#                                                                                                                                                                                                                                                                                                                      '[{'id': '90950d33-d701-4d35-9f79-8d9ba191ff4a', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Ultra.2010', 'status': 'Official'}]',
#                                                                                                                                                                          '[{'id': 'a677340d-1aff-40c7-b2b1-12d379688d4f', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Harmony', 'status': 'Official'}, {'id': '18291444-4940-467c-93fc-cf71245d57ee', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Harmony', 'status': 'Official'}]',
#         '[{'id': 'ae7351a5-180e-4b26-956a-1a6393a754f6', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Demonstration', 'status': 'Official'}, {'id': '60dbf2a4-ef03-4444-89b0-74ada78e3cae', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Demonstration', 'status': 'Official'}, {'id': 'b45fd7b8-ebe5-427e-a508-f39de560bb1a', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Demonstration', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                                         '[{'id': '91d16bed-970d-42ed-8538-3efd490ef457', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Ah Yeah', 'status': 'Official'}]',
#                                                                                                                                                    '[{'id': 'cdb24969-1afc-32ca-9140-d87fa69620d5', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Hello Good Morning', 'status': 'Official'}, {'id': '66117e7b-6922-4163-8b78-d37e4886a9f7', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Hello Good Morning', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                                     '[{'id': '8e1d9cdc-6502-4a98-9506-7a6af321a781', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Madd Circus', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                       '[{'id': 'd48f933a-f20d-440d-9061-25d68709bef7', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Dance Under the Influence', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                       '[{'id': '278c733e-dc82-4e6d-b384-3a335f9906f0', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Neon Future III (Remixes)', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                                       '[{'id': '2e4b1e7e-b14f-476a-900b-d3644ead4a67', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'This Time', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                                      '[{'id': 'd99a60a6-c500-429e-887e-296884f0baae', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Like to be', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                        '[{'id': 'bf3a93da-7dc3-4892-8d76-6ac8fde1c53b', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Faccio quello che voglio', 'status': 'Official'}]',
#                                                                                                                                                         '[{'id': '76517098-0d95-4c6b-bcca-4ba852159340', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Drunk Groove (edit)', 'status': 'Official'}, {'id': '20f7027f-a3ad-4ed1-8aa2-28b7f2c12236', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Drunk Groove', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                      '[{'id': '1ff3de56-227f-4a92-adb4-c08f5dd1ed6b', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Mario Cars 2: 64 THE REMIX', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                                '[{'id': 'affa4113-94dc-4d7f-99f1-423669add025', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'The burning song', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                                         '[{'id': 'dbb98b06-a76b-491a-b4f5-8f5386a09e7d', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Kashmir', 'status': 'Official'}]',
#                                                                                                                                                            '[{'id': '33c8467a-161a-490e-b2af-ed090eadb5d6', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Pink Champagne', 'status': 'Official'}, {'id': 'c8840c24-1a60-4451-a288-681b106d55c0', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Pink Champagne', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                                            '[{'id': '05960c6e-95a8-42ec-8743-85d79f3b0fbc', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'MORE', 'status': 'Official'}]',
#                                                                                                                                                                                                                                                                                                                        '[{'id': '938a5046-50dd-44f5-b13b-22edc056cd4e', 'status-id': '4e304316-386d-3409-af2e-78857eec5cfe', 'title': 'Peroxide', 'status': 'Official'}]']
# Length: 20, dtype: str
# - Column "tags" has 1 unique values.
#   -- Unique values are:
#  <StringArray>
# ['[{'count': 1, 'name': 'edm'}]']
# Length: 1, dtype: str
# - Column "secondary-types" has 2 unique values.
#   -- Unique values are:
#  <StringArray>
# [nan, '['Compilation']', '['Remix']']
# Length: 3, dtype: str
# - Column "secondary-type-ids" has 2 unique values.
#   -- Unique values are:
#  <StringArray>
# [                                       nan,
#  '['dd2a21e1-0c00-3729-a7a0-de60b84eb5d1']',
#  '['0c60f497-ff81-3818-befd-abfc84a4858b']']
# Length: 3, dtype: str
# edm    20
# dtype: int64

# %% [markdown]
# ## 6. Extract Label Metadata for EDM Classification
#
# Record labels serve as strong categorical predictors for EDM sub-genre classification (e.g., Anjunabeats for Trance, Drumcode for Techno). Here we look up label relations associated with our sample release groups via the MusicBrainz API.

# %%
def extract_release_labels(release_group_id, retries=2):
    """Fetch label names linked to a release group with basic retry logic."""
    url = "https://musicbrainz.org/ws/2/release/"
    params = {
        "release-group": release_group_id,
        "inc": "labels",
        "fmt": "json"
    }
    
    data = None
    for attempt in range(retries):
        # Increase timeout to 30 seconds to handle slow API responses
        data = fetch_raw_api_sample(url, params=params, headers=HEADERS, timeout=30)
        if data:
            break
        time.sleep(2)  # Wait before retrying on timeout/error
        
    if not data:
        return []

    labels = []
    for release in data.get("releases", []):
        for label_info in release.get("label-info", []):
            if label_info.get("label"):
                labels.append(label_info["label"]["name"])
                
    return list(set(labels))

# Test label extraction on the first 5 sample IDs
sample_ids = df_samples["id"].head(5)
label_results = {}

for rg_id in sample_ids:
    label_results[rg_id] = extract_release_labels(rg_id)
    time.sleep(RATE_LIMIT_DELAY)  # Maintain 1.2s delay between requests

# Format as DataFrame and render
df_labels = pd.DataFrame(list(label_results.items()), columns=["release_group_id", "labels"])
display(df_labels)
# Out:
# ERROR:root:API Request Failed for URL https://musicbrainz.org/ws/2/release/: 503 Server Error: Service Temporarily Unavailable for url: https://musicbrainz.org/ws/2/release/?release-group=7ba3a993-00b1-4627-a2e2-0e56127c039a&inc=labels&fmt=json
#                        release_group_id  \
# 0  4dc4fb78-e096-3f7b-9334-9defe9890ef8
# 1  3b766d4f-7b6b-44a3-9b52-bff158484f40
# 2  8a787daf-2a37-45a1-9ae1-53197eb79541
# 3  ddfc24ec-3376-4ad0-8279-ca47d579fcee
# 4  7ba3a993-00b1-4627-a2e2-0e56127c039a
#
#                                     labels
# 0               [avex trax, Bonnier Music]
# 1                                       []
# 2                            [Ultra Music]
# 3                           [Wolf Project]
# 4  [Parlophone, Disturbing London Records]

# %% [markdown]
# ## 7. Appendix: Bulk Data Collection Function
#
# The function below is kept for future reference when pulling the complete collection (5,746+ records). It includes explicit backoff logic for 503 Service Unavailable errors.

# %%
def fetch_raw_musicbrainz_records(total_count, tag=DEFAULT_TAG):
    """"
    Paginate and store complete unparsed records with backoff retry handling for 503 errors."""

    raw_records = []
    for offset in range(0, total_count, FETCH_LIMIT):
        params = {"query": f"tag:{tag}", "fmt": "json", "limit": FETCH_LIMIT, "offset": offset}
        success = False
        retries = 0
        
        while not success and retries < 3:
            try:
                res = requests.get(BASE_URL, params=params, headers=HEADERS, timeout=REQUEST_TIMEOUT)
                res.raise_for_status()
                raw_records.extend(res.json().get("release-groups", []))
                success = True
            except requests.exceptions.HTTPError as e:
                if res.status_code == 503:
                    retries += 1
                    print(f"HTTP 503 hit at offset {offset}. Backing off for {retries * 5} seconds...")
                    time.sleep(retries * 5)
                else:
                    print(f"HTTP Error at offset {offset}: {e}")
                    break
            except Exception as e:
                print(f"Request failed at offset {offset}: {e}")
                break
                
        time.sleep(RATE_LIMIT_DELAY)
    return raw_records

# Execute full bulk download when ready
# raw_full_data = fetch_raw_musicbrainz_records(total_count=total_edm_records)
